# %%
# %config IPCompleter.greedy=True
# %pip install boto3
# Out:
# ...
#      |████████████████████████████████| 131 kB 7.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.5 MB 7.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 79 kB 10.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3

# %%
client = boto3.client(
    's3',
    aws_access_key_id='AKIATJJR2V5VX6MZZBCA',
    aws_secret_access_key='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'
)
BUCKET = 's3groupturkey'   #s3://s3groupturkey/data/

# %%
#To Download 
FILE_NAME = 'data/data.csv' # DO NOT DELETE "data/"
client.download_file(BUCKET, FILE_NAME, '2test.csv')
#print(open('test.csv').read()) --> To read the document

# %%
#To upload
KEY_NAME = '2test.txt' # DO NOT DELETE "data/"
client.upload_file('data/hell0o.txt', BUCKET, KEY_NAME)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-17efeb54cd49> in <module>
#       1 #To upload
#       2 KEY_NAME = '2test.txt' # DO NOT DELETE "data/"
# ----> 3 client.upload_file('data/hell0o.txt', BUCKET, KEY_NAME)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     127     """
#     128     with S3Transfer(self, Config) as transfer:
# --> 129         return transfer.upload_file(
#     130             filename=Filename, bucket=Bucket, key=Key,
#     131             extra_args=ExtraArgs, callback=Callback)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     277             filename, bucket, key, extra_args, subscribers)
#     278         try:
# ...

# %%
#response = client.list_objects_v2(
response = client.list_objects(
    Bucket=BUCKET,
    MaxKeys=50,
)

response
# Out:
# {'ResponseMetadata': {'RequestId': '3T6X4WXDHH50Z18P',
#   'HostId': 'KB4sZGP7TB4SULvv/cEcuxpUdPFA3I3PzJ492HtJL90l+fPU3pIuHCCct3NPL6yDrYg5IbYaOys=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'KB4sZGP7TB4SULvv/cEcuxpUdPFA3I3PzJ492HtJL90l+fPU3pIuHCCct3NPL6yDrYg5IbYaOys=',
#    'x-amz-request-id': '3T6X4WXDHH50Z18P',
#    'date': 'Sat, 01 May 2021 19:47:43 GMT',
#    'x-amz-bucket-region': 'eu-central-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': '/data/hello.txt',
#    'LastModified': datetime.datetime(2021, 4, 20, 13, 21, 59, tzinfo=tzutc()),
#    'ETag': '"e56068064b115df66cea564717964071"',
#    'Size': 384965,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '5772195d61ea38f08e788d2faab9f6832e1618a2bd09f1a3d8618aff545f704e'}},
#   {'Key': 'code/',
# ...
